# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
from data import gather_data

# %%
def load_data():
    df = gather_data()

    df['model_name'] = df['model_name'].str.split('pysb.examples.').str.get(-1)
    df = df.loc[~df.model_name.isin(['ras_camp_pka'])]
    df = df.loc[(df.n_sim < 2 ** 17) & (df.n_sim > 2 ** 7)]
    
    # rename gpus
    df.loc[df['gpu_name'] == 'gtx1080', 'gpu_name'] = 'GTX1080'
    df.loc[df['gpu_name'] == 'GeForce GTX 1060', 'gpu_name'] = 'GTX1060'
    df.loc[df['gpu_name'] == 'GeForce GTX 1080', 'gpu_name'] = 'GTX1080'

    df.loc[df['gpu_name'] == 'TeslaV100-SXM2-16GB', 'gpu_name'] = 'TeslaV100'
    df.loc[df['gpu_name'] == 'VOLTA_V100', 'gpu_name'] = 'TeslaV100'
    df.loc[df['gpu_name'] == 'Tesla K20c', 'gpu_name'] = 'K20c'

    # rename pcs
    df.loc[df['device_name'] == 'bad.mc.vanderbilt.edu', 'device_name'] = 'bad'
    df.loc[df['device_name'] == 'ip-172-31-22-73', 'device_name'] = 'aws'

    # rename simulators
    df.loc[df['simulator'] == 'gpu_ssa', 'simulator'] = 'cuda'
    df.loc[df['simulator'] == 'cl_amd_gpu', 'simulator'] = 'opencl'
    df.loc[df['simulator'] == 'cl_amd', 'simulator'] = 'opencl'
    df.loc[df['simulator'] == 'cl_nvidia', 'simulator'] = 'opencl'
    df.loc[df['simulator'] == 'cl', 'simulator'] = 'opencl'


    crit = (df.simulator == 'stochkit') & (df.n_cpu == 64)
    df.loc[crit, 'simulator'] = 'stochkit_64'


    df.loc[(df['gpu_name'] == 'i5_6500T') & (df['simulator'] == 'cl_intel_gpu'), 'gpu_name'] = 'HD530'
    
    df['sim_card'] = df['gpu_name'] + '_' + df['simulator']
    df.sim_time = df.sim_time.astype('float')
    return df

def print_opts(d):
    print('\npc name : {}'.format(' '.join(sorted(d['device_name'].unique()))))
    print('model_name : {}'.format(' '.join(sorted(d['model_name'].unique()))))
    print('simulator : {}'.format(' '.join(sorted(d['simulator'].unique()))))
    print('gpu_name : {}'.format(' '.join(sorted(d['gpu_name'].unique()))))
    print('sim_card : {}'.format(' '.join(sorted(d['sim_card'].unique()))))

# %%
df = load_data()
print_opts(df)
gpu_only = ['cuda', 'opencl']
gpu_only = df.loc[df.simulator.isin(gpu_only)].copy()
print_opts(gpu_only)
# Out:
# pc name : aws bad beerus buu desktop-5v8h22a desktop-und9l5u diablo mule pct piccolo picollo puma
# model_name : earm_1_0 kinase_cascade michment schloegl schlogl
# simulator : bng cl_amd_cpu cl_intel cl_intel_cpu cl_intel_gpu cuda opencl stochkit stochkit_64
# gpu_name : GTX1060 GTX1070 GTX1080 GTX980Ti HD530 HD7970 RTX2080 Ryzen_1600x Ryzen_3900x TeslaK20c TeslaV100 i5_6500T x86_64
# sim_card : GTX1060_bng GTX1060_cuda GTX1070_cuda GTX1070_opencl GTX1080_cuda GTX1080_opencl GTX980Ti_cuda GTX980Ti_opencl HD530_cl_intel_gpu HD7970_opencl RTX2080_bng RTX2080_cuda RTX2080_opencl RTX2080_stochkit Ryzen_1600x_cl_amd_cpu Ryzen_1600x_opencl Ryzen_3900x_cl_amd_cpu TeslaK20c_cuda TeslaK20c_opencl TeslaV100_bng TeslaV100_cuda TeslaV100_opencl TeslaV100_stochkit TeslaV100_stochkit_64 i5_6500T_cl_intel i5_6500T_cl_intel_cpu x86_64_cl_amd_cpu
#
# pc name : aws bad buu diablo mule piccolo picollo puma
# model_name : earm_1_0 kinase_cascade michment schloegl schlogl
# simulator : cuda opencl
# gpu_name : GTX1060 GTX1070 GTX1080 GTX980Ti HD7970 RTX2080 Ryzen_1600x TeslaK20c TeslaV100
# sim_card : GTX1060_cuda GTX1070_cuda GTX1070_opencl GTX1080_cuda GTX1080_opencl GTX980Ti_cuda GTX980Ti_opencl HD7970_opencl RTX2080_cuda RTX2080_opencl Ryzen_1600x_opencl TeslaK20c_cuda TeslaK20c_opencl TeslaV100_cuda TeslaV100_opencl

# %%
main_pcs = ['aws', 'bad']
tesla_results = df.loc[df.device_name.isin(main_pcs)].copy()

# %%
print_opts(tesla_results)
# Out:
# pc name : aws bad
# model_name : earm_1_0 kinase_cascade michment schlogl
# simulator : bng cuda opencl stochkit stochkit_64
# gpu_name : TeslaV100
# sim_card : TeslaV100_bng TeslaV100_cuda TeslaV100_opencl TeslaV100_stochkit TeslaV100_stochkit_64

# %%
tesla_results.loc[tesla_results.model_name.isin(['earm_1_0',])]
# Out:
#   device_name  end_time   gpu_name model_name  n_sim  n_ts       sim_time  \
# 1         bad     20000  TeslaV100   earm_1_0    256   101    6348.137200
# 2         bad     20000  TeslaV100   earm_1_0    512   101   12628.227800
# 3         bad     20000  TeslaV100   earm_1_0   1024   101   25805.277000
# 4         bad     20000  TeslaV100   earm_1_0   2048   101   53670.920300
# 5         bad     20000  TeslaV100   earm_1_0   4096   101  113075.984700
# 6         bad     20000  TeslaV100   earm_1_0   8192   101  203555.371500
# 7         bad     20000  TeslaV100   earm_1_0  16384   101  404603.918500
# 8         bad     20000  TeslaV100   earm_1_0  32768   101  827438.203000
# 1         bad     20000  TeslaV100   earm_1_0    256   101     216.748763
# 2         bad     20000  TeslaV100   earm_1_0    512   101     205.838771
# 3         bad     20000  TeslaV100   earm_1_0   1024   101     204.041840
# 4         bad     20000  TeslaV100   earm_1_0   2048   101     209.452895
# 5         bad     20000  TeslaV100   earm_1_0   4096   101     207.043270
# 6         bad     20000  TeslaV100   earm_1_0   8192   101     236.805615
# 7         bad     20000  TeslaV100   earm_1_0  16384   101     375.101417
# 8         bad     20000  TeslaV100   earm_1_0  32768   101     870.268681
# 9         bad     20000  TeslaV100   earm_1_0  65536   101    1610.579342
# 1         bad     20000  TeslaV100   earm_1_0    256   101    2115.360000
# 2         bad     20000  TeslaV100   earm_1_0    512   101    4104.660000
# 3         bad     20000  TeslaV100   earm_1_0   1024   101    8150.940000
# 4         bad     20000  TeslaV100   earm_1_0   2048   101   16577.100000
# 5         bad     20000  TeslaV100   earm_1_0   4096   101   32606.800000
# 6         bad     20000  TeslaV100   earm_1_0   8192   101   66849.000000
# 7         bad     20000  TeslaV100   earm_1_0  16384   101  133109.000000
# 8         bad     20000  TeslaV100   earm_1_0  32768   101  259961.000000
# 9         bad     20000  TeslaV100   earm_1_0  65536   101  520748.000000
# 1         bad     20000  TeslaV100   earm_1_0    256   101     104.160000
# 2         bad     20000  TeslaV100   earm_1_0    512   101     168.929000
# 3         bad     20000  TeslaV100   earm_1_0   1024   101     313.073000
# 4         bad     20000  TeslaV100   earm_1_0   2048   101     593.390000
# 5         bad     20000  TeslaV100   earm_1_0   4096   101    1163.140000
# 6         bad     20000  TeslaV100   earm_1_0   8192   101    2296.050000
# 7         bad     20000  TeslaV100   earm_1_0  16384   101    4535.860000
# 8         bad     20000  TeslaV100   earm_1_0  32768   101    9144.920000
# 9         bad     20000  TeslaV100   earm_1_0  65536   101   18158.800000
# 1         aws     20000  TeslaV100   earm_1_0    256   101     378.818682
# 2         aws     20000  TeslaV100   earm_1_0    512   101     389.539825
# 3         aws     20000  TeslaV100   earm_1_0   1024   101     391.391531
# 4         aws     20000  TeslaV100   earm_1_0   2048   101     399.208319
# 5         aws     20000  TeslaV100   earm_1_0   4096   101     399.755187
# 6         aws     20000  TeslaV100   earm_1_0   8192   101     400.283757
# 7         aws     20000  TeslaV100   earm_1_0  16384   101     494.274389
# 8         aws     20000  TeslaV100   earm_1_0  32768   101    1005.734138
# 9         aws     20000  TeslaV100   earm_1_0  65536   101    1933.242428
#
#      simulator     total_time  n_cpu               sim_card
# 1          bng    6356.825094      1          TeslaV100_bng
# 2          bng   12645.359526      1          TeslaV100_bng
# 3          bng   25839.436697      1          TeslaV100_bng
# 4          bng   53742.258672      1          TeslaV100_bng
# 5          bng  113218.913081      1          TeslaV100_bng
# 6          bng  203817.357286      1          TeslaV100_bng
# 7          bng  405138.645481      1          TeslaV100_bng
# 8          bng  828541.440838      1          TeslaV100_bng
# 1         cuda     216.950264      1         TeslaV100_cuda
# 2         cuda     206.103830      1         TeslaV100_cuda
# 3         cuda     204.441112      1         TeslaV100_cuda
# 4         cuda     210.098116      1         TeslaV100_cuda
# 5         cuda     208.188765      1         TeslaV100_cuda
# 6         cuda     238.956008      1         TeslaV100_cuda
# 7         cuda     379.384224      1         TeslaV100_cuda
# 8         cuda     878.628316      1         TeslaV100_cuda
# 9         cuda    1627.183066      1         TeslaV100_cuda
# 1     stochkit    2116.625165      1     TeslaV100_stochkit
# 2     stochkit    4106.966527      1     TeslaV100_stochkit
# 3     stochkit    8155.342855      1     TeslaV100_stochkit
# 4     stochkit   16585.730410      1     TeslaV100_stochkit
# 5     stochkit   32622.987857      1     TeslaV100_stochkit
# 6     stochkit   66880.907689      1     TeslaV100_stochkit
# 7     stochkit  133172.797450      1     TeslaV100_stochkit
# 8     stochkit  260089.077420      1     TeslaV100_stochkit
# 9     stochkit  521000.943842      1     TeslaV100_stochkit
# 1  stochkit_64     105.471157     64  TeslaV100_stochkit_64
# 2  stochkit_64     171.246095     64  TeslaV100_stochkit_64
# 3  stochkit_64     317.408580     64  TeslaV100_stochkit_64
# 4  stochkit_64     601.777051     64  TeslaV100_stochkit_64
# 5  stochkit_64    1179.424125     64  TeslaV100_stochkit_64
# 6  stochkit_64    2327.955931     64  TeslaV100_stochkit_64
# 7  stochkit_64    4599.690459     64  TeslaV100_stochkit_64
# 8  stochkit_64    9272.081717     64  TeslaV100_stochkit_64
# 9  stochkit_64   18412.238340     64  TeslaV100_stochkit_64
# 1       opencl     379.136798      1       TeslaV100_opencl
# 2       opencl     390.034225      1       TeslaV100_opencl
# 3       opencl     392.218483      1       TeslaV100_opencl
# 4       opencl     400.740016      1       TeslaV100_opencl
# 5       opencl     402.743970      1       TeslaV100_opencl
# 6       opencl     405.992210      1       TeslaV100_opencl
# 7       opencl     505.633983      1       TeslaV100_opencl
# 8       opencl    1028.246537      1       TeslaV100_opencl
# 9       opencl    1979.010817      1       TeslaV100_opencl

# %%
tesla_results.dtypes
# Out:
# device_name     object
# end_time         int64
# gpu_name        object
# model_name      object
# n_sim            int64
# n_ts             int64
# sim_time       float64
# simulator       object
# total_time     float64
# n_cpu            int64
# sim_card        object
# dtype: object

# %%
tesla_results.head(10)
# Out:
#   device_name  end_time   gpu_name      model_name  n_sim  n_ts     sim_time  \
# 1         bad     20000  TeslaV100        earm_1_0    256   101    6348.1372
# 2         bad     20000  TeslaV100        earm_1_0    512   101   12628.2278
# 3         bad     20000  TeslaV100        earm_1_0   1024   101   25805.2770
# 4         bad     20000  TeslaV100        earm_1_0   2048   101   53670.9203
# 5         bad     20000  TeslaV100        earm_1_0   4096   101  113075.9847
# 6         bad     20000  TeslaV100        earm_1_0   8192   101  203555.3715
# 7         bad     20000  TeslaV100        earm_1_0  16384   101  404603.9185
# 8         bad     20000  TeslaV100        earm_1_0  32768   101  827438.2030
# 1         bad       100  TeslaV100  kinase_cascade    256   101    1051.3700
# 2         bad       100  TeslaV100  kinase_cascade    512   101    2102.8100
#
#   simulator     total_time  n_cpu       sim_card
# 1       bng    6356.825094      1  TeslaV100_bng
# 2       bng   12645.359526      1  TeslaV100_bng
# 3       bng   25839.436697      1  TeslaV100_bng
# 4       bng   53742.258672      1  TeslaV100_bng
# 5       bng  113218.913081      1  TeslaV100_bng
# 6       bng  203817.357286      1  TeslaV100_bng
# 7       bng  405138.645481      1  TeslaV100_bng
# 8       bng  828541.440838      1  TeslaV100_bng
# 1       bng    1056.029964      1  TeslaV100_bng
# 2       bng    2111.618109      1  TeslaV100_bng

# %%
def compare_times(data, save_name="time_compare"):
#     ['Michaelis Menten', 'Schlögl', 'JNK Activation Cascade', 'EARM 1.0']
    data.loc[data.model_name=='michment', 'model_name'] = 'Michaelis Menten'
    data.loc[data.model_name=='earm_1_0', 'model_name'] = 'EARM 1.0'
    data.loc[data.model_name=='kinase_cascade', 'model_name'] = 'JNK Activation Cascade'
    data.loc[data.model_name=='schlogl', 'model_name'] = 'Schlögl'
         
    g = sns.catplot(
        x="n_sim", y="sim_time", hue="simulator", 
        col="model_name", kind="point", data=data, 
        sharey=False, col_wrap=2, height=4, 
        col_order = ['Michaelis Menten', 'Schlögl', 'JNK Activation Cascade', 'EARM 1.0'],
        hue_order = ['stochkit', 'stochkit_64', 'bng', 'cuda', 'opencl'],
        markers=['o', '*', '+', '<', '^']
    )
    g.set_titles("{col_name}")
    g.set_axis_labels("Number of simulations", "Simulation time(s)")
    g.set(yscale="log")    
    locs, labels = plt.xticks()
    plt.setp(labels, rotation=45)
    g.set_xticklabels(labels, rotation=45)
    plt.savefig('{}.png'.format(save_name), dpi=300, bbox_inches='tight')
    plt.savefig('{}.pdf'.format(save_name), dpi=300, bbox_inches='tight')
    
compare_times(tesla_results)

# %%
def plot_earm(data, save_name="time_compare"):
    earm_only = data.loc[data.model_name == 'EARM 1.0'].copy()
    earm_only.to_csv('earm_timing.csv')
#     earm_only.loc[earm_only.model_name=='earm_1_0', 'model_name'] = 'EARM 1.0'
    display(earm_only.head(10))
#     earm_only = pd.pivot_table(
#         earm_only[['n_sim', 'simulator', 'sim_time']],
# #         index=['model_name'],
#         columns='simulator',
#         values='sim_time'
#     )
#     g = sns.scatterplot( data=earm_only, x="n_sim", y="sim_time", hue="simulator")
    g = sns.catplot(
        x="n_sim", y="sim_time", hue="simulator", 
        col="model_name", kind="point", data=earm_only, 
        sharey=False, #col_wrap=1, height=1, 
        col_order = [ 'EARM 1.0'],
        hue_order = ['stochkit', 'stochkit_64', 'bng', 'cuda', 'opencl'],
        markers=['o', '*', '+', '<', '^']
    )
    g.set_titles("{col_name}")
    g.set_axis_labels("Number of simulations", "Simulation time(s)")
    g.set(yscale="log")    
    locs, labels = plt.xticks()
    plt.setp(labels, rotation=45)
    g.set_xticklabels(labels, rotation=45)
    plt.savefig('{}.png'.format(save_name), dpi=300, bbox_inches='tight')
    plt.savefig('{}.pdf'.format(save_name), dpi=300, bbox_inches='tight')
    
plot_earm(tesla_results, 'earm_only_timing')

# %%
def plot_ratio(data, save_name="bng_gpu_ratio"):
    """
    Plots the ratio of BNG run times to GPU_SSA run times
    """
    d = data.loc[data.model_name == 'EARM 1.0'].copy()
    d = pd.pivot_table(
        d[['model_name', 'n_sim', 'simulator', 'sim_time']],
        index=['model_name', 'n_sim'],
        columns='simulator',
        values='sim_time'
    )
    

    d['ratio_bng'] = d['bng'] / d['cuda']
    d['ratio_stochkit'] = d['stochkit'] / d['cuda']
    d['ratio_stochkit_64_bng'] = d['bng'] / d['stochkit_64']
    d['ratio_stochkit_64'] = d['stochkit_64'] / d['cuda']
    print(d['ratio_stochkit_64_bng'] )
    d.reset_index(inplace=True)    
    fig = plt.figure(figsize=(3, 3))    
    ax = plt.subplot(1, 1, 1)
#     df = d.loc[['n_sim', 'ratio_bng', 'ratio_stochkit', 'ratio_stochkit_64']]
    df = d.copy()
    l1,= plt.plot(df['n_sim'], df['ratio_bng'], 'x-r', label='ratio_bng')
    l2,= plt.plot(df['n_sim'], df['ratio_stochkit'], 'o-k', label='ratio_stochkit')
    l3,= plt.plot(df['n_sim'], df['ratio_stochkit_64'], '^-b', label='ratio_stochkit_64')
    
    ax.set_xscale('log', basex=2)    
    ax.set_yscale('log', basey=10) 
    plt.ylabel("Simulation time ratio")
    plt.xlabel("Number of simulations")
#     plt.xticks([])
#     plt.xlabel('')
#     plt.ylabel('')
    lgd = fig.legend(
        [l1, l2, l3,],
        ["bng/cuda", "stochkit/cuda", "stochkit_64/cuda"],
        fancybox=True, shadow=True, 
        bbox_to_anchor=(1.5, .45),
    )
    plt.subplots_adjust(left=0.07, right=0.93, wspace=0.25, hspace=0.15)
#     plt.suptitle('TeslaV1000 Speedup', size=16)
    plt.savefig('{}.png'.format(save_name), dpi=300, bbox_inches='tight', bbox_extra_artists=(lgd,),)
    plt.savefig('{}.pdf'.format(save_name), dpi=300, bbox_inches='tight', bbox_extra_artists=(lgd,),)
plot_ratio(tesla_results)
# Out:
# model_name  n_sim
# EARM 1.0    256      60.946018
#             512      74.754647
#             1024     82.425751
#             2048     90.447969
#             4096     97.216143
#             8192     88.654590
#             16384    89.201148
#             32768    90.480639
#             65536          NaN
# Name: ratio_stochkit_64_bng, dtype: float64

# %%
def plot_ratio(data, save_name="bng_gpu_ratio"):
    """
    Plots the ratio of BNG run times to GPU_SSA run times
    """

    d = pd.pivot_table(
        data[['model_name', 'n_sim', 'simulator', 'sim_time']],
        index=['model_name', 'n_sim'],
        columns='simulator',
        values='sim_time'
    )
    

    d['ratio_bng'] = d['bng'] / d['cuda']
    d['ratio_stochkit'] = d['stochkit'] / d['cuda']
    d['ratio_stochkit_64'] = d['stochkit_64'] / d['cuda']
    def f2(x):
        return '{0:.3f}'.format(x)
    d.to_latex('sum_table_latex.tex', 
               formatters={'bng': f2, 'cuda':f2, 'opencl':f2, 'stochkit':f2, 'stochkit_64':f2},
               bold_rows=True)
#     print(d[['ratio_bng', 'ratio_stochkit', 'ratio_stochkit_64']])
    d.reset_index(inplace=True)
    d.to_csv('all_times.csv')
    
    count = 1
    fig = plt.figure(figsize=(8, 9))
    for i in ['Michaelis Menten', 'Schlögl', 'JNK Activation Cascade', 'EARM 1.0']:
        
        ax = plt.subplot(2,2, count)
        plt.title(i)
        df = d.loc[d.model_name==i][['n_sim', 'ratio_bng', 'ratio_stochkit', 'ratio_stochkit_64']]
        l1,= plt.plot(df['n_sim'], df['ratio_bng'], 'x-r', label='ratio_bng')
        l2,= plt.plot(df['n_sim'], df['ratio_stochkit'], 'o-k', label='ratio_stochkit')
        l3,= plt.plot(df['n_sim'], df['ratio_stochkit_64'], '^-b', label='ratio_stochkit_64')
        ax.set_xscale('log', basex=2)    
        ax.set_yscale('log', basey=10) 
        plt.ylabel("Simulation time ratio")
        plt.xlabel("Number of simulations")
        if count in (1,2):
            plt.xlabel('')
            plt.xticks([])
        if count in (2, 4):
            plt.ylabel('')
        count+=1
    lgd = fig.legend(
        [l1, l2, l3],
        ["bng/cuda", "stochkit/cuda", "stochkit_64/cuda"],
        fancybox=True, shadow=True, 
        bbox_to_anchor=(1.2, .48),
    )
    plt.subplots_adjust(left=0.07, right=0.93, wspace=0.25, hspace=0.15)
    plt.suptitle('TeslaV1000 Speedup', size=16)
    plt.savefig('{}.png'.format(save_name), dpi=300, bbox_inches='tight', bbox_extra_artists=(lgd,),)
    plt.savefig('{}.pdf'.format(save_name), dpi=300, bbox_inches='tight', bbox_extra_artists=(lgd,),)
plot_ratio(tesla_results)

# %%
def plot_ratio_cuda_opencl(data, save_name="opencl_cl_ratio"):
    """
    Plots the ratio of BNG run times to GPU_SSA run times
    """
    df_gpu = data.loc[~data.gpu_name.isin(['GTX1060'])].copy()
    d = pd.pivot_table(
        df_gpu[['model_name', 'n_sim', 'simulator', 'sim_time', 'gpu_name']],
        index=['model_name',  'gpu_name', 'n_sim',],
        columns='simulator',
        values='sim_time'
    )
    
    
    def f2(x):
        return '{0:.3f}'.format(x)
    d.to_latex('sum_table_latex.tex', 
               formatters={'bng': f2, 'cuda':f2, 'opencl':f2, 'stochkit':f2, 'stochkit_64':f2},
               bold_rows=True)
    d['ratio'] = d['opencl'] / d['cuda']
#     print(d[['ratio_bng', 'ratio_stochkit', 'ratio_stochkit_64']])
    d.reset_index(inplace=True)
#     d.to_csv('all_times.csv')
    
    count = 1
    fig = plt.figure(figsize=(8, 9))
    for i in ['michment', 'schlogl', 'kinase_cascade', 'earm_1_0']:
        
        ax = plt.subplot(2,2, count)
        plt.title(i)
        df = d.loc[d.model_name==i][['n_sim', 'ratio', 'gpu_name']]
        print(df.gpu_name.unique())
        gpus = [ 'GTX980Ti', 'GTX1080', 'RTX2080', 'TeslaK20c', 'TeslaV100']
        legends = []
        labels = []
        for i in gpus:
            dd = df.loc[df.gpu_name==i].copy()
            dd.sort_values('n_sim', inplace=True)
            l1,= plt.plot(dd['n_sim'], dd['ratio'], 'x-', label=i)
            
            legends.append(l1)
            labels.append(i)
        ax.set_xscale('log', basex=2)    
#         ax.set_yscale('log', basey=10) 
        plt.ylabel("Simulation time ratio")
        plt.xlabel("Number of simulations")
        
        if count in (1,2):
            plt.xlabel('')
            plt.xticks([])
        if count in (2, 4):
            plt.ylabel('')
        count+=1
        lgd = fig.legend(
            legends, labels,
            fancybox=True, shadow=True, 
            bbox_to_anchor=(1.2, .48),
        )
    plt.subplots_adjust(left=0.07, right=0.93, wspace=0.25, hspace=0.15)
    plt.suptitle('OpenCL vs CUDA on Nvidia GPUs', size=16)
    plt.savefig('{}.png'.format(save_name), dpi=300, bbox_inches='tight')# bbox_extra_artists=(lgd,),)
    plt.savefig('{}.pdf'.format(save_name), dpi=300, bbox_inches='tight')#bbox_extra_artists=(lgd,),)
plot_ratio_cuda_opencl(gpu_only)
# Out:
# ['GTX1070' 'GTX1080' 'GTX980Ti' 'HD7970' 'RTX2080' 'Ryzen_1600x'
#  'TeslaK20c' 'TeslaV100']
# ['GTX1070' 'GTX1080' 'GTX980Ti' 'HD7970' 'RTX2080' 'Ryzen_1600x'
#  'TeslaK20c' 'TeslaV100']
# ['GTX1080' 'GTX980Ti' 'HD7970' 'RTX2080' 'TeslaK20c' 'TeslaV100']
# ['GTX1070' 'GTX1080' 'GTX980Ti' 'HD7970' 'RTX2080' 'TeslaK20c' 'TeslaV100']

# %%
def compare_gpus():
    pal = sns.light_palette("purple", as_cmap=True)
    local_df = df.copy()
    print(df.simulator.unique())
    gpus = [
        'cuda', 
        'opencl', 
        'cl_amd_cpu',
        #'cl_intel_gpu', 'cl_amd', 'cl_nvidia'
    ]
    
    df_gpu =local_df.loc[local_df.simulator.isin(gpus)].copy()
#     df_gpu = gpu_only.copy()
    models = [
        'michment',
        'schlogl',
        'kinase_cascade',
        'earm_1_0',
    ]
    df_gpu.loc[df_gpu.model_name=='michment', 'model_name'] = 'Michaelis Menten'
    df_gpu.loc[df_gpu.model_name=='earm_1_0', 'model_name'] = 'EARM 1.0'
    df_gpu.loc[df_gpu.model_name=='kinase_cascade', 'model_name'] = 'JNK Activation Cascade'
    df_gpu.loc[df_gpu.model_name=='schlogl', 'model_name'] = 'Schlögl'
    
    models = ['Michaelis Menten', 'Schlögl', 'JNK Activation Cascade', 'EARM 1.0']
    df_gpu = df_gpu.loc[df_gpu.model_name.isin(models)].copy()
    df_gpu = df_gpu.loc[~df_gpu.gpu_name.isin(['GTX1060'])]

    fig = plt.figure(figsize=(12, 16))

    for n, m in enumerate(models):
        subset = df_gpu.loc[df_gpu['model_name'] == m].copy()

        d = pd.pivot_table(
            subset, index='sim_card', columns='n_sim', values='sim_time',
            fill_value=np.nan,
        )
        print(d.index.values)
        keep = [
#             'Ryzen_3900x_cl_amd_cpu',
#             'HD7970_opencl',
#             'GTX980Ti_opencl', 
            'GTX980Ti_cuda',
#             'GTX1080_opencl', 
            'GTX1080_cuda', 
#             'RTX2080_opencl',
            'RTX2080_cuda' ,
#             'TeslaK20c_opencl', 
            'TeslaK20c_cuda',
#             'TeslaV100_opencl', 
            'TeslaV100_cuda',
        ]
#         if m == 'EARM 1.0':
#             keep.remove('HD7970_opencl')
        f = '.2f'
        if m in ('Michaelis Menten', 'Schlögl'):
            f = '.3f'
        d = d.reindex(keep)
        ax = fig.add_subplot(4, 1, n + 1)
        ax.set_title(m)
        sns.heatmap(data=d, cmap=pal, linewidths=0.01, vmin=0, annot=True,
                    fmt=f, ax=ax)

#     plt.tight_layout()
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9, hspace=.4)
    plt.savefig("compare_gpus.png", bbox_inches='tight', dpi=300)
    plt.show()


compare_gpus()
# Out:
# ['bng' 'cuda' 'stochkit' 'stochkit_64' 'cl_amd_cpu' 'opencl'
#  'cl_intel_cpu' 'cl_intel_gpu']
# ['GTX1070_cuda' 'GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl'
#  'GTX980Ti_cuda' 'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_cuda'
#  'RTX2080_opencl' 'Ryzen_1600x_cl_amd_cpu' 'Ryzen_1600x_opencl'
#  'Ryzen_3900x_cl_amd_cpu' 'TeslaK20c_cuda' 'TeslaK20c_opencl'
#  'TeslaV100_cuda' 'TeslaV100_opencl' 'x86_64_cl_amd_cpu']
# ['GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda'
#  'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_cuda' 'RTX2080_opencl'
#  'Ryzen_1600x_cl_amd_cpu' 'Ryzen_1600x_opencl' 'Ryzen_3900x_cl_amd_cpu'
#  'TeslaK20c_cuda' 'TeslaK20c_opencl' 'TeslaV100_cuda' 'TeslaV100_opencl'
#  'x86_64_cl_amd_cpu']
# ['GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda' 'GTX980Ti_opencl'
#  'HD7970_opencl' 'RTX2080_cuda' 'RTX2080_opencl' 'Ryzen_1600x_cl_amd_cpu'
#  'Ryzen_3900x_cl_amd_cpu' 'TeslaK20c_cuda' 'TeslaK20c_opencl'
#  'TeslaV100_cuda' 'TeslaV100_opencl' 'x86_64_cl_amd_cpu']
# ['GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda'
#  'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_cuda' 'RTX2080_opencl'
#  'Ryzen_1600x_cl_amd_cpu' 'Ryzen_3900x_cl_amd_cpu' 'TeslaK20c_cuda'
#  'TeslaK20c_opencl' 'TeslaV100_cuda' 'TeslaV100_opencl']

# %%
def compare_gpus():
    pal = sns.light_palette("purple", as_cmap=True)
    local_df = df.copy()
    print(df.simulator.unique())
    gpus = [
        'cuda', 
        'opencl', 
        'cl_amd_cpu',
        #'cl_intel_gpu', 'cl_amd', 'cl_nvidia'
    ]
    
    df_gpu =local_df.loc[local_df.simulator.isin(gpus)].copy()
#     df_gpu = gpu_only.copy()
    models = [
        'michment',
        'schlogl',
        'kinase_cascade',
        'earm_1_0',
    ]
    df_gpu.loc[df_gpu.model_name=='michment', 'model_name'] = 'Michaelis Menten'
    df_gpu.loc[df_gpu.model_name=='earm_1_0', 'model_name'] = 'EARM 1.0'
    df_gpu.loc[df_gpu.model_name=='kinase_cascade', 'model_name'] = 'JNK Activation Cascade'
    df_gpu.loc[df_gpu.model_name=='schlogl', 'model_name'] = 'Schlögl'
    
    models = ['EARM 1.0']
    df_gpu = df_gpu.loc[df_gpu.model_name.isin(models)].copy()
    df_gpu = df_gpu.loc[~df_gpu.gpu_name.isin(['GTX1060'])]

    fig = plt.figure(figsize=(12, 16))

    for n, m in enumerate(models):
        subset = df_gpu.loc[df_gpu['model_name'] == m].copy()

        d = pd.pivot_table(
            subset, index='sim_card', columns='n_sim', values='sim_time',
            fill_value=np.nan,
        )
        print(d.index.values)
        keep = [
#             'Ryzen_3900x_cl_amd_cpu',
#             'HD7970_opencl',
#             'GTX980Ti_opencl', 
            'GTX980Ti_cuda',
#             'GTX1080_opencl', 
            'GTX1080_cuda', 
#             'RTX2080_opencl',
            'RTX2080_cuda' ,
#             'TeslaK20c_opencl', 
            'TeslaK20c_cuda',
#             'TeslaV100_opencl', 
            'TeslaV100_cuda',
        ]
#         if m == 'EARM 1.0':
#             keep.remove('HD7970_opencl')
        f = '.2f'
        if m in ('Michaelis Menten', 'Schlögl'):
            f = '.3f'
        d = d.reindex(keep)
        ax = fig.add_subplot(4, 1, n + 1)
        ax.set_title(m)
        sns.heatmap(data=d, cmap=pal, linewidths=0.01, vmin=0, annot=True,
                    fmt=f, ax=ax)

#     plt.tight_layout()
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9, hspace=.4)
    plt.savefig("compare_gpus.png", bbox_inches='tight', dpi=300)
    plt.show()


compare_gpus()
# Out:
# ['bng' 'cuda' 'stochkit' 'stochkit_64' 'cl_amd_cpu' 'opencl'
#  'cl_intel_cpu' 'cl_intel_gpu']
# ['GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda'
#  'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_cuda' 'RTX2080_opencl'
#  'Ryzen_1600x_cl_amd_cpu' 'Ryzen_3900x_cl_amd_cpu' 'TeslaK20c_cuda'
#  'TeslaK20c_opencl' 'TeslaV100_cuda' 'TeslaV100_opencl']

# %%
def compare_opencl_vs_cuda():
    pal = sns.light_palette("purple", as_cmap=True)
    local_df = df.copy()
    print(df.simulator.unique())
    gpus = [
        'cuda', 
        'opencl', 
        'cl_amd_cpu',
        #'cl_intel_gpu', 'cl_amd', 'cl_nvidia'
    ]
    
#     df_gpu =local_df.loc[local_df.simulator.isin(gpus)].copy()
    df_gpu = local_df.copy()
    models = [
#         'michment',
#         'schlogl',
#         'kinase_cascade',
        'earm_1_0',
    ]
    df_gpu.loc[df_gpu.model_name=='michment', 'model_name'] = 'Michaelis Menten'
    df_gpu.loc[df_gpu.model_name=='earm_1_0', 'model_name'] = 'EARM 1.0'
    df_gpu.loc[df_gpu.model_name=='kinase_cascade', 'model_name'] = 'JNK Activation Cascade'
    
    df_gpu.loc[df_gpu.model_name=='schlogl', 'model_name'] = 'Schlögl'
    
    df_gpu.loc[df_gpu.sim_card=='RTX2080_bng', 'sim_card'] = 'BNG'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_stochkit_64', 'sim_card'] = 'StochKit_64'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_stochkit', 'sim_card'] = 'StochKit_1'
    
    
    models = ['EARM 1.0']
    models = ['Schlögl']
    df_gpu = df_gpu.loc[df_gpu.model_name.isin(models)].copy()
    df_gpu = df_gpu.loc[~df_gpu.gpu_name.isin(['GTX1060'])]

    fig = plt.figure(figsize=(12, 6))
    
    for n, m in enumerate(models):
        subset = df_gpu.loc[df_gpu['model_name'] == m].copy()

        d = pd.pivot_table(
            subset, index='sim_card', columns='n_sim', values='sim_time',
            fill_value=np.nan,
        )
        
        print(d.index.values)
        keep = [
#             'BNG','StochKit_64', 'StochKit_1',
#             'i5_6500T_cl_intel_cpu',
#             'Ryzen_1600x_cl_amd_cpu', 
#             'Ryzen_3900x_cl_amd_cpu',
            'HD7970_opencl',
            'GTX980Ti_cuda', 'GTX980Ti_opencl',
            'GTX1080_cuda', 'GTX1080_opencl',
            'RTX2080_cuda', 'RTX2080_opencl',
            'TeslaK20c_cuda', 'TeslaK20c_opencl',
            'TeslaV100_cuda', 'TeslaV100_opencl',
            
        ]
#         if m == 'EARM 1.0':
#             keep.remove('HD7970_opencl')
        f = '.1f'
        if m in ('Michaelis Menten', 'Schlögl'):
            f = '.2f'
        d = d.reindex(keep)
        ax = fig.add_subplot(1,1,1)
        ax.set_title(m)
        sns.heatmap(data=d, cmap=pal, linewidths=0.01, vmin=0, annot=True,
                    fmt=f, ax=ax)

#     plt.tight_layout()
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9, hspace=.4)
    plt.savefig("compare_opencl.png", bbox_inches='tight', dpi=300)
    plt.show()


compare_opencl_vs_cuda()
# Out:
# ['bng' 'cuda' 'stochkit' 'stochkit_64' 'cl_amd_cpu' 'opencl'
#  'cl_intel_cpu' 'cl_intel_gpu']
# ['BNG' 'GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda'
#  'GTX980Ti_opencl' 'HD530_cl_intel_gpu' 'HD7970_opencl' 'RTX2080_cuda'
#  'RTX2080_opencl' 'RTX2080_stochkit' 'Ryzen_1600x_cl_amd_cpu'
#  'Ryzen_1600x_opencl' 'Ryzen_3900x_cl_amd_cpu' 'StochKit_1' 'StochKit_64'
#  'TeslaK20c_cuda' 'TeslaK20c_opencl' 'TeslaV100_bng' 'TeslaV100_cuda'
#  'TeslaV100_opencl' 'i5_6500T_cl_intel_cpu' 'x86_64_cl_amd_cpu']

# %%
def compare_cpu():
    pal = sns.light_palette("purple", as_cmap=True)
    local_df = df.copy()
    print(df.simulator.unique())

    df_gpu = local_df.copy()
    df_gpu.loc[df_gpu.model_name=='schlogl', 'model_name'] = 'Schlögl'
    df_gpu.loc[df_gpu.model_name=='earm_1_0', 'model_name'] = 'EARM 1.0'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_bng', 'sim_card'] = 'BNG'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_stochkit_64', 'sim_card'] = 'StochKit_64'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_stochkit', 'sim_card'] = 'StochKit_1'
    
    
    df_gpu.loc[df_gpu.sim_card=='Ryzen_1600x_cl_amd_cpu', 'sim_card'] = 'Ryzen_1600x_12'
    df_gpu.loc[df_gpu.sim_card=='Ryzen_3900x_cl_amd_cpu', 'sim_card'] = 'Ryzen_3900x_24'
    df_gpu.loc[df_gpu.sim_card=='i5_6500T_cl_intel_cpu', 'sim_card'] = 'i5_6500T_4'
    
    
    models = ['Schlögl']
    df_gpu = df_gpu.loc[df_gpu.model_name.isin(models)].copy()

    fig = plt.figure(figsize=(14, 4))
    
    for n, m in enumerate(models):
        subset = df_gpu.loc[df_gpu['model_name'] == m].copy()

        d = pd.pivot_table(
            subset, index='sim_card', columns='n_sim', values='sim_time',
            fill_value=np.nan,
        )
        
        print(d.index.values)
        keep = [
            'BNG',
            'StochKit_1',
            'StochKit_64', 
            'i5_6500T_4',
            'Ryzen_1600x_12', 
            'Ryzen_3900x_24',
#             'HD7970_opencl',
#             'GTX980Ti_cuda', 'GTX980Ti_opencl',
#             'GTX1080_cuda', 'GTX1080_opencl',
#             'RTX2080_cuda', 'RTX2080_opencl',
#             'TeslaK20c_cuda', 'TeslaK20c_opencl',
#             'TeslaV100_cuda', 'TeslaV100_opencl',
            
        ]
#         if m == 'EARM 1.0':
#             keep.remove('HD7970_opencl')
        f = '.1f'
        if m in ('Michaelis Menten', 'Schlögl'):
            f = '.2f'
        d = d.reindex(keep)
        ax = fig.add_subplot(1,1,1)
        ax.set_title(m)
        sns.heatmap(data=d, cmap=pal, linewidths=0.01, vmin=0, annot=True,
                    fmt=f, ax=ax)

#     plt.tight_layout()
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9, hspace=.4)
    plt.savefig("compare_cpus_earm.png", bbox_inches='tight', dpi=300)
    plt.show()


compare_cpu()
# Out:
# ['bng' 'cuda' 'stochkit' 'stochkit_64' 'cl_amd_cpu' 'opencl'
#  'cl_intel_cpu' 'cl_intel_gpu']
# ['BNG' 'GTX1060_bng' 'GTX1060_cuda' 'GTX1070_opencl' 'GTX1080_cuda'
#  'GTX1080_opencl' 'GTX980Ti_cuda' 'GTX980Ti_opencl' 'HD530_cl_intel_gpu'
#  'HD7970_opencl' 'RTX2080_bng' 'RTX2080_cuda' 'RTX2080_opencl'
#  'RTX2080_stochkit' 'Ryzen_1600x_12' 'Ryzen_1600x_opencl' 'Ryzen_3900x_24'
#  'StochKit_1' 'StochKit_64' 'TeslaK20c_cuda' 'TeslaK20c_opencl'
#  'TeslaV100_cuda' 'TeslaV100_opencl' 'i5_6500T_4' 'x86_64_cl_amd_cpu']

# %%
def timing_summary():
    pal = sns.light_palette("purple", as_cmap=True)
    local_df = df.copy()
    print(df.simulator.unique())
    gpus = [
        'cuda', 
        'opencl', 
        'cl_amd_cpu',
        'bng', 
        'stochkit', 
        'stochkit_64',
        
    ]
    
    df_gpu =local_df.loc[local_df.simulator.isin(gpus)].copy()
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_stochkit', 'sim_card']= 'StochKit'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_stochkit_64', 'sim_card']= 'StochKit_64'
    df_gpu.loc[df_gpu.sim_card=='TeslaV100_bng', 'sim_card']= 'BNG'
    models = [
        'michment',
        'schlogl',
        'kinase_cascade',
        'earm_1_0',
    ]
    df_gpu = df_gpu.loc[df_gpu.model_name.isin(models)].copy()
    df_gpu = df_gpu.loc[~df_gpu.gpu_name.isin(['GTX1060'])]

    fig = plt.figure(figsize=(12, 18))

    for n, m in enumerate(models):
        subset = df_gpu.loc[df_gpu['model_name'] == m].copy()
        print(subset)
       
        d = pd.pivot_table(
            subset, index='sim_card', columns='n_sim', values='sim_time',
            fill_value=np.nan,
        )
        print(d.index.values)
        keep = [
#             'BNG', 'StochKit', 'StochKit_64',
            'Ryzen_3900x_cl_amd_cpu',
            'HD7970_opencl',
            'GTX980Ti_opencl', 'GTX980Ti_cuda',
            'GTX1080_opencl', 'GTX1080_cuda', 
            'RTX2080_opencl','RTX2080_cuda' ,
            'TeslaK20c_opencl', 'TeslaK20c_cuda',
            'TeslaV100_opencl', 'TeslaV100_cuda',
        ]
        if model == ''
        d = d.reindex(keep)
        ax = fig.add_subplot(5, 1, n + 1)
        ax.set_title(m)
        sns.heatmap(data=d, cmap=pal, linewidths=0.01, vmin=0, annot=True,
                    fmt=".3f", ax=ax)

    plt.tight_layout()
    plt.savefig("compare_gpus.png", bbox_inches='tight', dpi=300)
    plt.show()


timing_summary()
# Out:
# ['bng' 'cuda' 'stochkit' 'stochkit_64' 'cl_amd_cpu' 'opencl' 'cl_intel'
#  'cl_intel_cpu' 'cl_intel_gpu']
#      device_name  end_time   gpu_name model_name  n_sim  n_ts    sim_time  \
# 1            bad       100  TeslaV100   michment    256   101    0.755400
# 2            bad       100  TeslaV100   michment    512   101    1.462000
# 3            bad       100  TeslaV100   michment   1024   101    2.926800
# 4            bad       100  TeslaV100   michment   2048   101    5.858100
# 5            bad       100  TeslaV100   michment   4096   101   11.741400
# 6            bad       100  TeslaV100   michment   8192   101   23.522000
# 7            bad       100  TeslaV100   michment  16384   101   47.253000
# 8            bad       100  TeslaV100   michment  32768   101   94.376000
# 9            bad       100  TeslaV100   michment  65536   101  189.680200
# 1            bad       100  TeslaV100   michment    256   101    0.001811
# 2            bad       100  TeslaV100   michment    512   101    0.002303
# 3            bad       100  TeslaV100   michment   1024   101    0.001850
# 4            bad       100  TeslaV100   michment   2048   101    0.002120
# 5            bad       100  TeslaV100   michment   4096   101    0.002405
# 6            bad       100  TeslaV100   michment   8192   101    0.003312
# 7            bad       100  TeslaV100   michment  16384   101    0.005290
# 8            bad       100  TeslaV100   michment  32768   101    0.010229
# 9            bad       100  TeslaV100   michment  65536   101    0.021587
# 1            bad       100  TeslaV100   michment    256   101    0.095768
# 2            bad       100  TeslaV100   michment    512   101    0.101108
# 3            bad       100  TeslaV100   michment   1024   101    0.118150
# 4            bad       100  TeslaV100   michment   2048   101    0.159830
# 5            bad       100  TeslaV100   michment   4096   101    0.245081
# 6            bad       100  TeslaV100   michment   8192   101    0.402092
# 7            bad       100  TeslaV100   michment  16384   101    0.863718
# 8            bad       100  TeslaV100   michment  32768   101    1.543250
# 9            bad       100  TeslaV100   michment  65536   101    3.167060
# 1            bad       100  TeslaV100   michment    256   101    0.160116
# 2            bad       100  TeslaV100   michment    512   101    0.319431
# 3            bad       100  TeslaV100   michment   1024   101    0.629187
# ...          ...       ...        ...        ...    ...   ...         ...
# 3179         buu       100    RTX2080   michment  16384   101    0.020540
# 3180         buu       100    RTX2080   michment  32768   101    0.038411
# 3181         buu       100    RTX2080   michment  65536   101    0.067374
# 3203         buu       100    RTX2080   michment    256   101    0.007433
# 3204         buu       100    RTX2080   michment    512   101    0.010416
# 3205         buu       100    RTX2080   michment   1024   101    0.020338
# 3206         buu       100    RTX2080   michment   2048   101    0.031548
# 3207         buu       100    RTX2080   michment   4096   101    0.049779
# 3208         buu       100    RTX2080   michment   8192   101    0.087688
# 3209         buu       100    RTX2080   michment  16384   101    0.163815
# 3210         buu       100    RTX2080   michment  32768   101    0.315914
# 3211         buu       100    RTX2080   michment  65536   101    0.619036
# 3213         buu       100    RTX2080   michment    256   101    0.003561
# 3214         buu       100    RTX2080   michment    512   101    0.003736
# 3215         buu       100    RTX2080   michment   1024   101    0.003900
# 3216         buu       100    RTX2080   michment   2048   101    0.004599
# 3217         buu       100    RTX2080   michment   4096   101    0.006239
# 3218         buu       100    RTX2080   michment   8192   101    0.010444
# 3219         buu       100    RTX2080   michment  16384   101    0.020028
# 3220         buu       100    RTX2080   michment  32768   101    0.041512
# 3221         buu       100    RTX2080   michment  65536   101    0.067649
# 3232         buu       100     x86_64   michment    256   101    0.005019
# 3233         buu       100     x86_64   michment    512   101    0.010187
# 3234         buu       100     x86_64   michment   1024   101    0.019737
# 3235         buu       100     x86_64   michment   2048   101    0.033557
# 3236         buu       100     x86_64   michment   4096   101    0.051836
# 3237         buu       100     x86_64   michment   8192   101    0.089304
# 3238         buu       100     x86_64   michment  16384   101    0.162022
# 3239         buu       100     x86_64   michment  32768   101    0.323510
# 3240         buu       100     x86_64   michment  65536   101    0.619451
#
#         simulator  total_time  n_cpu           sim_card
# 1             bng    2.826094      1                BNG
# 2             bng    5.359418      1                BNG
# 3             bng   10.504914      1                BNG
# 4             bng   20.897599      1                BNG
# 5             bng   41.869638      1                BNG
# 6             bng   83.917209      1                BNG
# 7             bng  170.467126      1                BNG
# 8             bng  343.994827      1                BNG
# 9             bng  715.293008      1                BNG
# 1            cuda    0.133345      1     TeslaV100_cuda
# 2            cuda    0.159804      1     TeslaV100_cuda
# 3            cuda    0.210924      1     TeslaV100_cuda
# 4            cuda    0.335172      1     TeslaV100_cuda
# 5            cuda    0.517723      1     TeslaV100_cuda
# 6            cuda    0.938295      1     TeslaV100_cuda
# 7            cuda    1.794200      1     TeslaV100_cuda
# 8            cuda    3.440641      1     TeslaV100_cuda
# 9            cuda    6.755818      1     TeslaV100_cuda
# 1     stochkit_64    0.484594     64        StochKit_64
# 2     stochkit_64    0.780007     64        StochKit_64
# 3     stochkit_64    1.382734     64        StochKit_64
# 4     stochkit_64    2.549093     64        StochKit_64
# 5     stochkit_64    4.898831     64        StochKit_64
# 6     stochkit_64    9.643367     64        StochKit_64
# 7     stochkit_64   19.357718     64        StochKit_64
# 8     stochkit_64   37.782259     64        StochKit_64
# 9     stochkit_64   75.925916     64        StochKit_64
# 1        stochkit    0.474718      1           StochKit
# 2        stochkit    0.929237      1           StochKit
# 3        stochkit    1.788389      1           StochKit
# ...           ...         ...    ...                ...
# 3179         cuda    1.741662      1       RTX2080_cuda
# 3180         cuda    3.455668      1       RTX2080_cuda
# 3181         cuda    6.880261      1       RTX2080_cuda
# 3203       opencl    0.041088      1     RTX2080_opencl
# 3204       opencl    0.071540      1     RTX2080_opencl
# 3205       opencl    0.127843      1     RTX2080_opencl
# 3206       opencl    0.239052      1     RTX2080_opencl
# 3207       opencl    0.455708      1     RTX2080_opencl
# 3208       opencl    0.929729      1     RTX2080_opencl
# 3209       opencl    1.765028      1     RTX2080_opencl
# 3210       opencl    3.501925      1     RTX2080_opencl
# 3211       opencl    7.249506      1     RTX2080_opencl
# 3213         cuda    0.108424      1       RTX2080_cuda
# 3214         cuda    0.141292      1       RTX2080_cuda
# 3215         cuda    0.186897      1       RTX2080_cuda
# 3216         cuda    0.281215      1       RTX2080_cuda
# 3217         cuda    0.485518      1       RTX2080_cuda
# 3218         cuda    0.916073      1       RTX2080_cuda
# 3219         cuda    1.680454      1       RTX2080_cuda
# 3220         cuda    3.271777      1       RTX2080_cuda
# 3221         cuda    6.584344      1       RTX2080_cuda
# 3232   cl_amd_cpu    0.035648      1  x86_64_cl_amd_cpu
# 3233   cl_amd_cpu    0.071369      1  x86_64_cl_amd_cpu
# 3234   cl_amd_cpu    0.130143      1  x86_64_cl_amd_cpu
# 3235   cl_amd_cpu    0.240818      1  x86_64_cl_amd_cpu
# 3236   cl_amd_cpu    0.455854      1  x86_64_cl_amd_cpu
# 3237   cl_amd_cpu    0.918043      1  x86_64_cl_amd_cpu
# 3238   cl_amd_cpu    1.750399      1  x86_64_cl_amd_cpu
# 3239   cl_amd_cpu    3.511965      1  x86_64_cl_amd_cpu
# 3240   cl_amd_cpu    7.194320      1  x86_64_cl_amd_cpu
#
# [773 rows x 11 columns]
# ['BNG' 'GTX1070_cuda' 'GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl'
#  'GTX980Ti_cuda' 'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_bng'
#  'RTX2080_cuda' 'RTX2080_opencl' 'RTX2080_stochkit'
#  'Ryzen_1600x_cl_amd_cpu' 'Ryzen_1600x_opencl' 'Ryzen_3900x_cl_amd_cpu'
#  'StochKit' 'StochKit_64' 'TeslaK20c_cuda' 'TeslaK20c_opencl'
#  'TeslaV100_cuda' 'TeslaV100_opencl' 'x86_64_cl_amd_cpu']
#      device_name  end_time   gpu_name model_name  n_sim  n_ts     sim_time  \
# 1            bad       100  TeslaV100    schlogl    256   101     9.519300
# 2            bad       100  TeslaV100    schlogl    512   101    19.117600
# 3            bad       100  TeslaV100    schlogl   1024   101    38.555200
# 4            bad       100  TeslaV100    schlogl   2048   101    77.159100
# 5            bad       100  TeslaV100    schlogl   4096   101   154.493200
# 6            bad       100  TeslaV100    schlogl   8192   101   310.030500
# 7            bad       100  TeslaV100    schlogl  16384   101   617.243900
# 8            bad       100  TeslaV100    schlogl  32768   101  1235.296900
# 9            bad       100  TeslaV100    schlogl  65536   101  2467.469200
# 1            bad       100  TeslaV100    schlogl    256   101     0.258138
# 2            bad       100  TeslaV100    schlogl    512   101     0.188396
# 3            bad       100  TeslaV100    schlogl   1024   101     0.290919
# 4            bad       100  TeslaV100    schlogl   2048   101     0.267284
# 5            bad       100  TeslaV100    schlogl   4096   101     0.282394
# 6            bad       100  TeslaV100    schlogl   8192   101     0.284664
# 7            bad       100  TeslaV100    schlogl  16384   101     0.291189
# 8            bad       100  TeslaV100    schlogl  32768   101     0.305037
# 9            bad       100  TeslaV100    schlogl  65536   101     0.351212
# 1            bad       100  TeslaV100    schlogl    256   101     0.284816
# 2            bad       100  TeslaV100    schlogl    512   101     0.340183
# 3            bad       100  TeslaV100    schlogl   1024   101     0.601767
# 4            bad       100  TeslaV100    schlogl   2048   101     1.012130
# 5            bad       100  TeslaV100    schlogl   4096   101     1.818700
# 6            bad       100  TeslaV100    schlogl   8192   101     3.472080
# 7            bad       100  TeslaV100    schlogl  16384   101     6.716000
# 8            bad       100  TeslaV100    schlogl  32768   101    12.736300
# 9            bad       100  TeslaV100    schlogl  65536   101    20.597700
# 1            bad       100  TeslaV100    schlogl    256   101     2.206040
# 2            bad       100  TeslaV100    schlogl    512   101     4.602470
# 3            bad       100  TeslaV100    schlogl   1024   101     8.881260
# ...          ...       ...        ...        ...    ...   ...          ...
# 2775         buu       100    RTX2080    schlogl   8192   101     0.258778
# 2776         buu       100    RTX2080    schlogl  16384   101     0.491318
# 2777         buu       100    RTX2080    schlogl   1024   101     0.146046
# 2778         buu       100    RTX2080    schlogl   2048   101     0.147548
# 2779         buu       100    RTX2080    schlogl   4096   101     0.229688
# 2780         buu       100    RTX2080    schlogl   8192   101     0.246000
# 2781         buu       100    RTX2080    schlogl  16384   101     0.516642
# 2796         buu       100    RTX2080    schlogl   1024   101     1.384929
# 2797         buu       100    RTX2080    schlogl   2048   101     0.875497
# 2798         buu       100    RTX2080    schlogl   4096   101     0.827013
# 2799         buu       100    RTX2080    schlogl   8192   101     1.467718
# 2800         buu       100    RTX2080    schlogl  16384   101     2.002922
# 2802         buu       100    RTX2080    schlogl    256   101     0.135000
# 2803         buu       100    RTX2080    schlogl    512   101     0.905654
# 2804         buu       100    RTX2080    schlogl   1024   101     0.718188
# 2805         buu       100    RTX2080    schlogl   2048   101     1.171913
# 2806         buu       100    RTX2080    schlogl   4096   101     1.240646
# 2807         buu       100    RTX2080    schlogl   8192   101     1.503444
# 2808         buu       100    RTX2080    schlogl  16384   101     2.092549
# 2809         buu       100    RTX2080    schlogl  32768   101     2.739942
# 2810         buu       100    RTX2080    schlogl  65536   101     4.904636
# 2812         buu       100    RTX2080    schlogl    256   101     0.408437
# 2813         buu       100    RTX2080    schlogl    512   101     0.165054
# 2814         buu       100    RTX2080    schlogl   1024   101     1.027460
# 2815         buu       100    RTX2080    schlogl   2048   101     1.294375
# 2816         buu       100    RTX2080    schlogl   4096   101     1.187884
# 2817         buu       100    RTX2080    schlogl   8192   101     1.473717
# 2818         buu       100    RTX2080    schlogl  16384   101     2.161206
# 2819         buu       100    RTX2080    schlogl  32768   101     3.020124
# 2820         buu       100    RTX2080    schlogl  65536   101     4.992582
#
#         simulator   total_time  n_cpu        sim_card
# 1             bng    11.363641      1             BNG
# 2             bng    22.511872      1             BNG
# 3             bng    45.298450      1             BNG
# 4             bng    90.470282      1             BNG
# 5             bng   180.996673      1             BNG
# 6             bng   363.466923      1             BNG
# 7             bng   724.682155      1             BNG
# 8             bng  1457.027464      1             BNG
# 9             bng  2932.307964      1             BNG
# 1            cuda     0.374835      1  TeslaV100_cuda
# 2            cuda     0.316212      1  TeslaV100_cuda
# 3            cuda     0.446360      1  TeslaV100_cuda
# 4            cuda     0.485155      1  TeslaV100_cuda
# 5            cuda     0.573984      1  TeslaV100_cuda
# 6            cuda     0.764057      1  TeslaV100_cuda
# 7            cuda     1.180018      1  TeslaV100_cuda
# 8            cuda     1.939845      1  TeslaV100_cuda
# 9            cuda     3.598074      1  TeslaV100_cuda
# 1     stochkit_64     7.095875     64     StochKit_64
# 2     stochkit_64     7.601832     64     StochKit_64
# 3     stochkit_64     8.373968     64     StochKit_64
# 4     stochkit_64     9.848178     64     StochKit_64
# 5     stochkit_64    12.451156     64     StochKit_64
# 6     stochkit_64    17.821221     64     StochKit_64
# 7     stochkit_64    28.607393     64     StochKit_64
# 8     stochkit_64    50.277463     64     StochKit_64
# 9     stochkit_64    87.758497     64     StochKit_64
# 1        stochkit     9.149826      1        StochKit
# 2        stochkit    11.784785      1        StochKit
# 3        stochkit    16.546400      1        StochKit
# ...           ...          ...    ...             ...
# 2775       opencl     0.873776      1  RTX2080_opencl
# 2776       opencl     1.669641      1  RTX2080_opencl
# 2777       opencl     0.343889      1  RTX2080_opencl
# 2778       opencl     0.370636      1  RTX2080_opencl
# 2779       opencl     0.583729      1  RTX2080_opencl
# 2780       opencl     0.863030      1  RTX2080_opencl
# 2781       opencl     1.687755      1  RTX2080_opencl
# 2796       opencl     1.707517      1  RTX2080_opencl
# 2797       opencl     1.092978      1  RTX2080_opencl
# 2798       opencl     1.176004      1  RTX2080_opencl
# 2799       opencl     2.118717      1  RTX2080_opencl
# 2800       opencl     3.141932      1  RTX2080_opencl
# 2802       opencl     0.235020      1  RTX2080_opencl
# 2803       opencl     1.019664      1  RTX2080_opencl
# 2804       opencl     0.867198      1  RTX2080_opencl
# 2805       opencl     1.383915      1  RTX2080_opencl
# 2806       opencl     1.588649      1  RTX2080_opencl
# 2807       opencl     2.111465      1  RTX2080_opencl
# 2808       opencl     3.251549      1  RTX2080_opencl
# 2809       opencl     4.982942      1  RTX2080_opencl
# 2810       opencl     9.241319      1  RTX2080_opencl
# 2812       opencl     0.511440      1  RTX2080_opencl
# 2813       opencl     0.279063      1  RTX2080_opencl
# 2814       opencl     1.177464      1  RTX2080_opencl
# 2815       opencl     1.508379      1  RTX2080_opencl
# 2816       opencl     1.533443      1  RTX2080_opencl
# 2817       opencl     2.071273      1  RTX2080_opencl
# 2818       opencl     3.312027      1  RTX2080_opencl
# 2819       opencl     5.234335      1  RTX2080_opencl
# 2820       opencl     9.321793      1  RTX2080_opencl
#
# [1764 rows x 11 columns]
# ['BNG' 'GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda'
#  'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_bng' 'RTX2080_cuda'
#  'RTX2080_opencl' 'RTX2080_stochkit' 'Ryzen_1600x_cl_amd_cpu'
#  'Ryzen_1600x_opencl' 'Ryzen_3900x_cl_amd_cpu' 'StochKit' 'StochKit_64'
#  'TeslaK20c_cuda' 'TeslaK20c_opencl' 'TeslaV100_cuda' 'TeslaV100_opencl'
#  'x86_64_cl_amd_cpu']
#      device_name  end_time     gpu_name      model_name  n_sim  n_ts  \
# 1            bad       100    TeslaV100  kinase_cascade    256   101
# 2            bad       100    TeslaV100  kinase_cascade    512   101
# 3            bad       100    TeslaV100  kinase_cascade   1024   101
# 4            bad       100    TeslaV100  kinase_cascade   2048   101
# 5            bad       100    TeslaV100  kinase_cascade   4096   101
# 6            bad       100    TeslaV100  kinase_cascade   8192   101
# 7            bad       100    TeslaV100  kinase_cascade  16384   101
# 8            bad       100    TeslaV100  kinase_cascade  32768   101
# 9            bad       100    TeslaV100  kinase_cascade  65536   101
# 1            bad       100    TeslaV100  kinase_cascade    256   101
# 2            bad       100    TeslaV100  kinase_cascade    512   101
# 3            bad       100    TeslaV100  kinase_cascade   1024   101
# 4            bad       100    TeslaV100  kinase_cascade   2048   101
# 5            bad       100    TeslaV100  kinase_cascade   4096   101
# 6            bad       100    TeslaV100  kinase_cascade   8192   101
# 7            bad       100    TeslaV100  kinase_cascade  16384   101
# 8            bad       100    TeslaV100  kinase_cascade  32768   101
# 9            bad       100    TeslaV100  kinase_cascade  65536   101
# 1            bad       100    TeslaV100  kinase_cascade    256   101
# 2            bad       100    TeslaV100  kinase_cascade    512   101
# 3            bad       100    TeslaV100  kinase_cascade   1024   101
# 4            bad       100    TeslaV100  kinase_cascade   2048   101
# 5            bad       100    TeslaV100  kinase_cascade   4096   101
# 6            bad       100    TeslaV100  kinase_cascade   8192   101
# 7            bad       100    TeslaV100  kinase_cascade  16384   101
# 8            bad       100    TeslaV100  kinase_cascade  32768   101
# 9            bad       100    TeslaV100  kinase_cascade  65536   101
# 1            bad       100    TeslaV100  kinase_cascade    256   101
# 2            bad       100    TeslaV100  kinase_cascade    512   101
# 3            bad       100    TeslaV100  kinase_cascade   1024   101
# ...          ...       ...          ...             ...    ...   ...
# 2741         buu       100  Ryzen_3900x  kinase_cascade   2048   101
# 2742         buu       100  Ryzen_3900x  kinase_cascade   4096   101
# 2743         buu       100  Ryzen_3900x  kinase_cascade   8192   101
# 2748         buu       100  Ryzen_3900x  kinase_cascade    256   101
# 2749         buu       100  Ryzen_3900x  kinase_cascade    512   101
# 2750         buu       100  Ryzen_3900x  kinase_cascade   1024   101
# 2751         buu       100  Ryzen_3900x  kinase_cascade   2048   101
# 2752         buu       100  Ryzen_3900x  kinase_cascade   4096   101
# 2753         buu       100  Ryzen_3900x  kinase_cascade   8192   101
# 2782         buu       100      RTX2080  kinase_cascade   1024   101
# 2783         buu       100      RTX2080  kinase_cascade   2048   101
# 2784         buu       100      RTX2080  kinase_cascade   4096   101
# 2785         buu       100      RTX2080  kinase_cascade   1024   101
# 2786         buu       100      RTX2080  kinase_cascade   2048   101
# 2787         buu       100      RTX2080  kinase_cascade   4096   101
# 2788         buu       100  Ryzen_3900x  kinase_cascade   1024   101
# 2830         buu       100  Ryzen_3900x  kinase_cascade    256   101
# 2831         buu       100  Ryzen_3900x  kinase_cascade    512   101
# 2832         buu       100  Ryzen_3900x  kinase_cascade   1024   101
# 2833         buu       100  Ryzen_3900x  kinase_cascade   2048   101
# 2834         buu       100  Ryzen_3900x  kinase_cascade   4096   101
# 2835         buu       100  Ryzen_3900x  kinase_cascade   8192   101
# 2836         buu       100  Ryzen_3900x  kinase_cascade  16384   101
# 2837         buu       100  Ryzen_3900x  kinase_cascade  32768   101
# 2838         buu       100  Ryzen_3900x  kinase_cascade  65536   101
# 3161         buu       100      RTX2080  kinase_cascade    256   101
# 3252         buu       100       x86_64  kinase_cascade    256   101
# 3253         buu       100       x86_64  kinase_cascade    512   101
# 3254         buu       100       x86_64  kinase_cascade   1024   101
# 3255         buu       100       x86_64  kinase_cascade   2048   101
#
#            sim_time    simulator     total_time  n_cpu                sim_card
# 1       1051.370000          bng    1056.029964      1                     BNG
# 2       2102.810000          bng    2111.618109      1                     BNG
# 3       4199.720000          bng    4216.653133      1                     BNG
# 4       8393.110000          bng    8427.760017      1                     BNG
# 5      16418.157500          bng   16482.714977      1                     BNG
# 6      32634.334300          bng   32765.910715      1                     BNG
# 7      65257.742000          bng   65523.183326      1                     BNG
# 8     130748.749700          bng  131302.953304      1                     BNG
# 9     261432.906800          bng  262500.829362      1                     BNG
# 1          5.297154         cuda       5.446778      1          TeslaV100_cuda
# 2          5.296954         cuda       5.471844      1          TeslaV100_cuda
# 3          5.298247         cuda       5.528868      1          TeslaV100_cuda
# 4          5.301056         cuda       5.639041      1          TeslaV100_cuda
# 5          5.309700         cuda       5.856876      1          TeslaV100_cuda
# 6          5.330646         cuda       6.329621      1          TeslaV100_cuda
# 7          6.200761         cuda       8.017534      1          TeslaV100_cuda
# 8         12.511591         cuda      16.096479      1          TeslaV100_cuda
# 9         23.795413         cuda      30.843978      1          TeslaV100_cuda
# 1        249.351000     stochkit     249.934428      1                StochKit
# 2        497.495000     stochkit     498.577029      1                StochKit
# 3        995.781000     stochkit     997.849908      1                StochKit
# 4       1939.520000     stochkit    1943.610697      1                StochKit
# 5       3993.200000     stochkit    4001.283189      1                StochKit
# 6       7976.930000     stochkit    7992.986216      1                StochKit
# 7      16007.700000     stochkit   16039.867086      1                StochKit
# 8      30782.200000     stochkit   30845.725385      1                StochKit
# 9      70123.800000     stochkit   70251.823636      1                StochKit
# 1         10.586300  stochkit_64      11.265841     64             StochKit_64
# 2         22.442900  stochkit_64      23.624865     64             StochKit_64
# 3         36.288700  stochkit_64      38.478038     64             StochKit_64
# ...             ...          ...            ...    ...                     ...
# 2741      65.244856   cl_amd_cpu      65.635859      1  Ryzen_3900x_cl_amd_cpu
# 2742     128.381119   cl_amd_cpu     129.138916      1  Ryzen_3900x_cl_amd_cpu
# 2743     256.254170   cl_amd_cpu     257.751754      1  Ryzen_3900x_cl_amd_cpu
# 2748       7.721481   cl_amd_cpu       7.792488      1  Ryzen_3900x_cl_amd_cpu
# 2749      15.588282   cl_amd_cpu      15.705283      1  Ryzen_3900x_cl_amd_cpu
# 2750      31.387363   cl_amd_cpu      31.598366      1  Ryzen_3900x_cl_amd_cpu
# 2751      62.608215   cl_amd_cpu      63.008215      1  Ryzen_3900x_cl_amd_cpu
# 2752     124.658055   cl_amd_cpu     125.440961      1  Ryzen_3900x_cl_amd_cpu
# 2753     248.269872   cl_amd_cpu     249.799613      1  Ryzen_3900x_cl_amd_cpu
# 2782      19.675580       opencl      20.229576      1          RTX2080_opencl
# 2783      19.526911       opencl      19.993783      1          RTX2080_opencl
# 2784      35.079281       opencl      35.913586      1          RTX2080_opencl
# 2785      15.303148       opencl      15.628147      1          RTX2080_opencl
# 2786      19.556893       opencl      20.023894      1          RTX2080_opencl
# 2787      26.264503       opencl      27.094878      1          RTX2080_opencl
# 2788      38.097744   cl_amd_cpu      38.575754      1  Ryzen_3900x_cl_amd_cpu
# 2830      15.848663   cl_amd_cpu      15.917662      1  Ryzen_3900x_cl_amd_cpu
# 2831      18.991146   cl_amd_cpu      19.107146      1  Ryzen_3900x_cl_amd_cpu
# 2832      38.128639   cl_amd_cpu      38.337638      1  Ryzen_3900x_cl_amd_cpu
# 2833      63.780896   cl_amd_cpu      64.177410      1  Ryzen_3900x_cl_amd_cpu
# 2834     127.504742   cl_amd_cpu     128.267742      1  Ryzen_3900x_cl_amd_cpu
# 2835     242.938372   cl_amd_cpu     244.466503      1  Ryzen_3900x_cl_amd_cpu
# 2836     485.920693   cl_amd_cpu     488.992752      1  Ryzen_3900x_cl_amd_cpu
# 2837     957.042539   cl_amd_cpu     963.054913      1  Ryzen_3900x_cl_amd_cpu
# 2838    1915.979956   cl_amd_cpu    1928.097774      1  Ryzen_3900x_cl_amd_cpu
# 3161      21.550302       opencl      21.675586      1          RTX2080_opencl
# 3252       7.781167   cl_amd_cpu       7.850201      1       x86_64_cl_amd_cpu
# 3253      15.681887   cl_amd_cpu      15.808637      1       x86_64_cl_amd_cpu
# 3254      30.740616   cl_amd_cpu      30.968741      1       x86_64_cl_amd_cpu
# 3255      61.570071   cl_amd_cpu      62.018708      1       x86_64_cl_amd_cpu
#
# [366 rows x 11 columns]
# ['BNG' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda' 'GTX980Ti_opencl'
#  'HD7970_opencl' 'RTX2080_bng' 'RTX2080_cuda' 'RTX2080_opencl'
#  'RTX2080_stochkit' 'Ryzen_1600x_cl_amd_cpu' 'Ryzen_3900x_cl_amd_cpu'
#  'StochKit' 'StochKit_64' 'TeslaK20c_cuda' 'TeslaK20c_opencl'
#  'TeslaV100_cuda' 'TeslaV100_opencl' 'x86_64_cl_amd_cpu']
#      device_name  end_time     gpu_name model_name  n_sim  n_ts  \
# 1            bad     20000    TeslaV100   earm_1_0    256   101
# 2            bad     20000    TeslaV100   earm_1_0    512   101
# 3            bad     20000    TeslaV100   earm_1_0   1024   101
# 4            bad     20000    TeslaV100   earm_1_0   2048   101
# 5            bad     20000    TeslaV100   earm_1_0   4096   101
# 6            bad     20000    TeslaV100   earm_1_0   8192   101
# 7            bad     20000    TeslaV100   earm_1_0  16384   101
# 8            bad     20000    TeslaV100   earm_1_0  32768   101
# 1            bad     20000    TeslaV100   earm_1_0    256   101
# 2            bad     20000    TeslaV100   earm_1_0    512   101
# 3            bad     20000    TeslaV100   earm_1_0   1024   101
# 4            bad     20000    TeslaV100   earm_1_0   2048   101
# 5            bad     20000    TeslaV100   earm_1_0   4096   101
# 6            bad     20000    TeslaV100   earm_1_0   8192   101
# 7            bad     20000    TeslaV100   earm_1_0  16384   101
# 8            bad     20000    TeslaV100   earm_1_0  32768   101
# 9            bad     20000    TeslaV100   earm_1_0  65536   101
# 1            bad     20000    TeslaV100   earm_1_0    256   101
# 2            bad     20000    TeslaV100   earm_1_0    512   101
# 3            bad     20000    TeslaV100   earm_1_0   1024   101
# 4            bad     20000    TeslaV100   earm_1_0   2048   101
# 5            bad     20000    TeslaV100   earm_1_0   4096   101
# 6            bad     20000    TeslaV100   earm_1_0   8192   101
# 7            bad     20000    TeslaV100   earm_1_0  16384   101
# 8            bad     20000    TeslaV100   earm_1_0  32768   101
# 9            bad     20000    TeslaV100   earm_1_0  65536   101
# 1            bad     20000    TeslaV100   earm_1_0    256   101
# 2            bad     20000    TeslaV100   earm_1_0    512   101
# 3            bad     20000    TeslaV100   earm_1_0   1024   101
# 4            bad     20000    TeslaV100   earm_1_0   2048   101
# ...          ...       ...          ...        ...    ...   ...
# 2849         buu     20000  Ryzen_3900x   earm_1_0   4096    10
# 2850         buu     20000  Ryzen_3900x   earm_1_0   8192    10
# 2851         buu     20000  Ryzen_3900x   earm_1_0  16384    10
# 2852         buu     20000  Ryzen_3900x   earm_1_0  32768    10
# 2853         buu     20000  Ryzen_3900x   earm_1_0  65536    10
# 2856         buu     20000  Ryzen_3900x   earm_1_0    256    10
# 2858         buu     20000  Ryzen_3900x   earm_1_0    256   101
# 2859         buu     20000  Ryzen_3900x   earm_1_0    512   101
# 2860         buu     20000  Ryzen_3900x   earm_1_0   1024   101
# 2861         buu     20000  Ryzen_3900x   earm_1_0   2048   101
# 2862         buu     20000  Ryzen_3900x   earm_1_0   4096   101
# 2863         buu     20000  Ryzen_3900x   earm_1_0   8192   101
# 2864         buu     20000  Ryzen_3900x   earm_1_0  16384   101
# 2865         buu     20000  Ryzen_3900x   earm_1_0  32768   101
# 2997         buu      5000       HD7970   earm_1_0    256   101
# 2998         buu      5000       HD7970   earm_1_0    512   101
# 2999         buu      5000       HD7970   earm_1_0   1024   101
# 3000         buu      5000       HD7970   earm_1_0   2048   101
# 3001         buu      5000       HD7970   earm_1_0   4096   101
# 3002         buu      5000       HD7970   earm_1_0   8192   101
# 3003         buu      5000       HD7970   earm_1_0  16384   101
# 3016         buu     20000      GTX1070   earm_1_0    256   101
# 3017         buu     20000      GTX1070   earm_1_0    512   101
# 3018         buu     20000      GTX1070   earm_1_0   1024   101
# 3019         buu     20000      GTX1070   earm_1_0   2048   101
# 3020         buu     20000      GTX1070   earm_1_0   4096   101
# 3022         buu     20000      RTX2080   earm_1_0   8192   101
# 3023         buu     20000      RTX2080   earm_1_0  16384   101
# 3024         buu     20000      RTX2080   earm_1_0  32768   101
# 3025         buu     20000      RTX2080   earm_1_0  65536   101
#
#            sim_time    simulator     total_time  n_cpu                sim_card
# 1       6348.137200          bng    6356.825094      1                     BNG
# 2      12628.227800          bng   12645.359526      1                     BNG
# 3      25805.277000          bng   25839.436697      1                     BNG
# 4      53670.920300          bng   53742.258672      1                     BNG
# 5     113075.984700          bng  113218.913081      1                     BNG
# 6     203555.371500          bng  203817.357286      1                     BNG
# 7     404603.918500          bng  405138.645481      1                     BNG
# 8     827438.203000          bng  828541.440838      1                     BNG
# 1        216.748763         cuda     216.950264      1          TeslaV100_cuda
# 2        205.838771         cuda     206.103830      1          TeslaV100_cuda
# 3        204.041840         cuda     204.441112      1          TeslaV100_cuda
# 4        209.452895         cuda     210.098116      1          TeslaV100_cuda
# 5        207.043270         cuda     208.188765      1          TeslaV100_cuda
# 6        236.805615         cuda     238.956008      1          TeslaV100_cuda
# 7        375.101417         cuda     379.384224      1          TeslaV100_cuda
# 8        870.268681         cuda     878.628316      1          TeslaV100_cuda
# 9       1610.579342         cuda    1627.183066      1          TeslaV100_cuda
# 1       2115.360000     stochkit    2116.625165      1                StochKit
# 2       4104.660000     stochkit    4106.966527      1                StochKit
# 3       8150.940000     stochkit    8155.342855      1                StochKit
# 4      16577.100000     stochkit   16585.730410      1                StochKit
# 5      32606.800000     stochkit   32622.987857      1                StochKit
# 6      66849.000000     stochkit   66880.907689      1                StochKit
# 7     133109.000000     stochkit  133172.797450      1                StochKit
# 8     259961.000000     stochkit  260089.077420      1                StochKit
# 9     520748.000000     stochkit  521000.943842      1                StochKit
# 1        104.160000  stochkit_64     105.471157     64             StochKit_64
# 2        168.929000  stochkit_64     171.246095     64             StochKit_64
# 3        313.073000  stochkit_64     317.408580     64             StochKit_64
# 4        593.390000  stochkit_64     601.777051     64             StochKit_64
# ...             ...          ...            ...    ...                     ...
# 2849    2066.548422   cl_amd_cpu    2068.655426      1  Ryzen_3900x_cl_amd_cpu
# 2850    4081.657955   cl_amd_cpu    4085.819934      1  Ryzen_3900x_cl_amd_cpu
# 2851    8190.835375   cl_amd_cpu    8198.869373      1  Ryzen_3900x_cl_amd_cpu
# 2852   16181.393638   cl_amd_cpu   16197.292738      1  Ryzen_3900x_cl_amd_cpu
# 2853   32311.920090   cl_amd_cpu   32344.138144      1  Ryzen_3900x_cl_amd_cpu
# 2856     143.123891   cl_amd_cpu     143.299037      1  Ryzen_3900x_cl_amd_cpu
# 2858     133.410284   cl_amd_cpu     133.584976      1  Ryzen_3900x_cl_amd_cpu
# 2859     264.842798   cl_amd_cpu     265.148052      1  Ryzen_3900x_cl_amd_cpu
# 2860     519.295613   cl_amd_cpu     519.849364      1  Ryzen_3900x_cl_amd_cpu
# 2861    1019.614258   cl_amd_cpu    1020.656133      1  Ryzen_3900x_cl_amd_cpu
# 2862    2023.450211   cl_amd_cpu    2025.542335      1  Ryzen_3900x_cl_amd_cpu
# 2863    4032.208771   cl_amd_cpu    4036.314170      1  Ryzen_3900x_cl_amd_cpu
# 2864    8047.032876   cl_amd_cpu    8055.124453      1  Ryzen_3900x_cl_amd_cpu
# 2865   16040.900249   cl_amd_cpu   16057.192412      1  Ryzen_3900x_cl_amd_cpu
# 2997       0.307256       opencl       0.564675      1           HD7970_opencl
# 2998       0.337282       opencl       0.723667      1           HD7970_opencl
# 2999       0.369308       opencl       1.006100      1           HD7970_opencl
# 3000       0.433360       opencl       1.580618      1           HD7970_opencl
# 3001       0.542470       opencl       2.772737      1           HD7970_opencl
# 3002       1.004837       opencl       5.296412      1           HD7970_opencl
# 3003       1.979667       opencl      10.340782      1           HD7970_opencl
# 3016     617.007983       opencl     617.258315      1          GTX1070_opencl
# 3017     613.141706       opencl     613.545731      1          GTX1070_opencl
# 3018     640.611057       opencl     641.296460      1          GTX1070_opencl
# 3019     722.810322       opencl     724.074337      1          GTX1070_opencl
# 3020     899.694182       opencl     902.178919      1          GTX1070_opencl
# 3022    1674.913200       opencl    1679.923614      1          RTX2080_opencl
# 3023    4327.414392       opencl    4337.165446      1          RTX2080_opencl
# 3024    6494.943955       opencl    6514.272094      1          RTX2080_opencl
# 3025   12784.721348       opencl   12823.702980      1          RTX2080_opencl
#
# [467 rows x 11 columns]
# ['BNG' 'GTX1070_opencl' 'GTX1080_cuda' 'GTX1080_opencl' 'GTX980Ti_cuda'
#  'GTX980Ti_opencl' 'HD7970_opencl' 'RTX2080_bng' 'RTX2080_cuda'
#  'RTX2080_opencl' 'RTX2080_stochkit' 'Ryzen_1600x_cl_amd_cpu'
#  'Ryzen_3900x_cl_amd_cpu' 'StochKit' 'StochKit_64' 'TeslaK20c_cuda'
#  'TeslaK20c_opencl' 'TeslaV100_cuda' 'TeslaV100_opencl']

# %%
times = pd.read_csv('Timings/times.csv')
times.head(10)
# Out:
#   device_name  end_time gpu_name              model_name  n_sim  n_ts  \
# 0         buu       100  RTX2080  pysb.examples.michment    128   101
# 1         buu       100  RTX2080  pysb.examples.michment    256   101
# 2         buu       100  RTX2080  pysb.examples.michment    512   101
# 3         buu       100  RTX2080  pysb.examples.michment   1024   101
# 4         buu       100  RTX2080  pysb.examples.michment   2048   101
# 5         buu       100  RTX2080  pysb.examples.michment   4096   101
# 6         buu       100  RTX2080  pysb.examples.michment   8192   101
# 7         buu       100  RTX2080  pysb.examples.michment  16384   101
# 8         buu       100  RTX2080  pysb.examples.michment  32768   101
# 9         buu       100  RTX2080  pysb.examples.michment    128   101
#
#    sim_time simulator  total_time
# 0  0.018014   gpu_ssa    1.389110
# 1  0.011009   gpu_ssa    1.380150
# 2  0.012010   gpu_ssa    1.411325
# 3  0.015023   gpu_ssa    1.471651
# 4  0.021017   gpu_ssa    1.499957
# 5  0.034029   gpu_ssa    1.718466
# 6  0.060059   gpu_ssa    2.020693
# 7  0.114095   gpu_ssa    2.697048
# 8  0.239200   gpu_ssa    3.967459
# 9  0.018013   gpu_ssa    1.568299

# %%
subset = times.loc[
    (times.gpu_name.isin(['HD7970'])) & (times.model_name.isin(['pysb.examples.earm_1_0']))
    & (times.simulator.isin(['cl']))
#     & (times.end_time ==20000)
]

# %%
subset
# Out:
#      device_name  end_time gpu_name              model_name  n_sim  n_ts  \
# 1380         buu     20000   HD7970  pysb.examples.earm_1_0     64   101
# 1381         buu     20000   HD7970  pysb.examples.earm_1_0    128   101
# 1382         buu     20000   HD7970  pysb.examples.earm_1_0    256   101
# 1383         buu     20000   HD7970  pysb.examples.earm_1_0    512   101
# 1384         buu     20000   HD7970  pysb.examples.earm_1_0   1024   101
#
#          sim_time simulator   total_time
# 1380     0.006021        cl     0.701000
# 1381     0.007000        cl     0.200001
# 1382  3273.787567        cl  3274.085575
# 1383  3769.838791        cl  3770.343795
# 1384  4193.768476        cl  4194.754476

# %%
subset.to_csv('t.csv')

# %%
94.45/25
# Out:
# 3.778

# %%
2100/60
# Out:
# 35.0
